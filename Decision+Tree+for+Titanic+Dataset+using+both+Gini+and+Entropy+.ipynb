# %%
import pandas as pd

# %%
df1=pd.read_csv("C://Users//kh.rahul//Downloads//titanic.csv")
df1.head(10)
df1.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df=df1

# %% [markdown]
# # Missing Value Treatment

# %%
pd.isnull(df).any()
pd.isnull(df).sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.Age = df.Age.fillna(df.Age.mean())

# %% [markdown]
# # Let us take the significant variables

# %%
input=df.drop(['Survived', 'Name', 'Ticket','Fare', 'PassengerId','Cabin','Embarked'], axis='columns')

# %%
input.Age = input.Age.fillna(input.Age.mean())

# %%
target=df.Survived

# %%
input
# Out:
#      Pclass     Sex        Age  SibSp  Parch
# 0         3    male  22.000000      1      0
# 1         1  female  38.000000      1      0
# 2         3  female  26.000000      0      0
# 3         1  female  35.000000      1      0
# 4         3    male  35.000000      0      0
# 5         3    male  29.699118      0      0
# 6         1    male  54.000000      0      0
# 7         3    male   2.000000      3      1
# 8         3  female  27.000000      0      2
# 9         2  female  14.000000      1      0
# 10        3  female   4.000000      1      1
# 11        1  female  58.000000      0      0
# 12        3    male  20.000000      0      0
# 13        3    male  39.000000      1      5
# 14        3  female  14.000000      0      0
# 15        2  female  55.000000      0      0
# 16        3    male   2.000000      4      1
# 17        2    male  29.699118      0      0
# 18        3  female  31.000000      1      0
# 19        3  female  29.699118      0      0
# ...

# %%
target
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
# 5      0
# 6      0
# 7      0
# 8      1
# 9      1
# 10     1
# 11     1
# 12     0
# 13     0
# 14     0
# 15     1
# 16     0
# 17     1
# 18     0
# 19     1
# 20     0
# 21     1
# 22     1
# 23     1
# 24     0
# 25     1
# 26     0
# 27     0
# 28     1
# 29     0
#       ..
# 861    0
# 862    1
# 863    0
# 864    0
# 865    1
# 866    1
# 867    0
# 868    0
# 869    1
# 870    0
# 871    1
# 872    0
# 873    0
# 874    1
# 875    1
# 876    0
# 877    0
# 878    0
# 879    1
# 880    1
# 881    0
# 882    0
# 883    0
# 884    0
# 885    0
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le_Sex = LabelEncoder()

# %%
input['Sex_n'] = le_Sex.fit_transform(input['Sex'])

# %%
input.head()
# Out:
#    Pclass     Sex   Age  SibSp  Parch  Sex_n
# 0       3    male  22.0      1      0      1
# 1       1  female  38.0      1      0      0
# 2       3  female  26.0      0      0      0
# 3       1  female  35.0      1      0      0
# 4       3    male  35.0      0      0      1

# %%
input=input.drop('Sex',axis='columns')

# %%
input
# Out:
#      Pclass        Age  SibSp  Parch  Sex_n
# 0         3  22.000000      1      0      1
# 1         1  38.000000      1      0      0
# 2         3  26.000000      0      0      0
# 3         1  35.000000      1      0      0
# 4         3  35.000000      0      0      1
# 5         3  29.699118      0      0      1
# 6         1  54.000000      0      0      1
# 7         3   2.000000      3      1      1
# 8         3  27.000000      0      2      0
# 9         2  14.000000      1      0      0
# 10        3   4.000000      1      1      0
# 11        1  58.000000      0      0      0
# 12        3  20.000000      0      0      1
# 13        3  39.000000      1      5      1
# 14        3  14.000000      0      0      0
# 15        2  55.000000      0      0      0
# 16        3   2.000000      4      1      1
# 17        2  29.699118      0      0      1
# 18        3  31.000000      1      0      0
# 19        3  29.699118      0      0      0
# ...

# %%
input['Age']=input['Age'].astype(int)

# %%
input.head()
# Out:
#    Pclass  Age  SibSp  Parch  Sex_n
# 0       3   22      1      0      1
# 1       1   38      1      0      0
# 2       3   26      0      0      0
# 3       1   35      1      0      0
# 4       3   35      0      0      1

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(input,target,test_size=0.2)

# %%
len(X_train)
# Out:
# 712

# %%
len(X_test)
# Out:
# 179

# %%
from sklearn import tree
model = tree.DecisionTreeClassifier()

# %% [markdown]
# # Le us use both Entropy and Gini

# %%
model1 = tree.DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
            max_features=None, max_leaf_nodes=None,
            min_impurity_split=1e-07, min_samples_leaf=1,
            min_samples_split=2, min_weight_fraction_leaf=0.0,
            presort=False, random_state=None, splitter='best')

# %%
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
model1.fit(X_train,y_train)
# Out:
# C:\Users\kh.rahul\Anaconda3\lib\site-packages\sklearn\tree\tree.py:282: DeprecationWarning: The min_impurity_split parameter is deprecated and will be removed in version 0.21. Use the min_impurity_decrease parameter instead.
#   DeprecationWarning)
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=1e-07,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
model.score(X_test,y_test)
# Out:
# 0.8044692737430168

# %%
model1.score(X_test,y_test)
# Out:
# 0.81564245810055869
